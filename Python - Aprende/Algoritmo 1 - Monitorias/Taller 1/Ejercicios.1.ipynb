# %%
while True:
    while True:
        edad = int(input("Digite su edad:"))
        if edad > 0:
            break
        else:
            print("Ingrese un valor de edad valido")

    if edad > 0 and edad <= 12:
        print("Usted es un niño")
    elif edad >= 13 and edad <= 17:
        print("Usted es un adolescente")
    elif edad >= 18 and edad <= 64:
        print("Usted es un adulto")
    else:
        print("Usted es un adulto mayor")

# %%
swich = True #Variable que controla la condicion de entrada

while swich == True:
    print("Tipos de Triangulo: \n Equilatero\n Isoseles \n escaleno ")
    Triangulo = input("Ingre el tipo de triangulo: ")
    if Triangulo == "si" or Triangulo =="SI" or Triangulo == "no" or Triangulo == "NO": # Validar si el tipo de triángulo ingresado coincide con los valores en la lista
        swich = False
    else:
        print("Tipo de triángulo no válido, intente nuevamente.")

if Triangulo == "equilatero" or Triangulo == "EQUILATERO":
    print(f"El triangulo {Triangulo}: Todos los lados son iguales")
elif Triangulo == "isoseles" or Triangulo == "ISOSELES":
    print(f"El triangulo {Triangulo}: Dos de sus lados son iguales")
else:
    print(f"El triangulo {Triangulo}: Todos sus lados son diferentes")
